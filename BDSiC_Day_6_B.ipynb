# %% [markdown]
# # Two main parts of any data visualization:
# 1. Technical
# * https://www.data-to-viz.com/
# * Best practice articles in Science/nature articles
# *  worst examples
#
# 2. Artistic/narrative:
# *
# The following has many citations in it about applying the hero’s journey to scientific communication
# https://www.crescenzotortora.com/hero_journey.htm* Tufte - napolean, john snow, florence nightingale (usual suspects)l

# %% [markdown]
# Visualization Presentation:
# https://www.data-to-viz.com/   <--(and their code in Python and R)
#
# https://statisticsbyjim.com/graphs/
#
# https://piktochart.com/blog/types-of-graphs/
#
# https://www.sciencedirect.com/science/article/pii/S2666389920301896
#
# https://www.nature.com/articles/d41586-023-03393-9
#
# https://www.edwardtufte.com/tufte/
#
# https://monachalabi.com/

# %% [markdown]
# ## Data Type determines the plot type:
# ### Variable types : Plots
# - statistical/distribution of quantitative variable
#     - single variable
#         - histogram
#         - densityplot
#     - single variable x categorical variable
#         - boxplot
# - count data
#     - count data x categorical variable
#         - barplot
#     - count data x 2 categorical variables
#         - grouped bar plot
#         - stacked bar plot
# - Directly view quantitative variables
#     - one variable x time
#         - line plot
#     - one variable x time x categorical variable
#         - multiple lines on the same plot
#     - two (or maybe 3) quantitative variables
#         - scatter plot

# %% [markdown]
# # Visualization Best Practices
# 1. Choose the right type of visualization
# 2. Be mindful when choosing colors
# 3. Label your axes
# 4. Make text big enough
# 5. Keep it simple
# 6. Less is more:
#     - Aim to improve your data:ink ratio
#     - Everything on the page should serve a purpose. If it doesn't, remove it.
